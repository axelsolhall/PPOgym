# %%
import gym
import torch
import numpy as np
from torch import nn, optim

# %%
# Initialize the CartPole environment
env = gym.make("CartPole-v1", render_mode="rgb_array")

state, info = env.reset()
action = env.action_space.sample()

state, reward, done, truncated, info = env.step(action)
print(f"State: {state}, Reward: {reward}, Done: {done}, Truncated: {truncated}, Info: {info}")
# Out:
# State: [ 0.01330669 -0.19223367  0.0312921   0.25859132], Reward: 1.0, Done: False, Truncated: False, Info: {}
# /Users/axelsolhall/miniconda3/envs/PPOgym/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
# Define the PPO agent's neural network
class PPOAgent(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(PPOAgent, self).__init__()
        
        # Common hidden layers
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU()
        )
        
        # Policy output: generates probabilities for actions
        self.policy = nn.Linear(64, output_dim)
        
        # Value output: predicts the expected return for a state
        self.value = nn.Linear(64, 1)

    def forward(self, x):
        x = self.fc(x)
        
        # Use softmax to ensure the policy output is a valid probability distribution
        policy_probs = torch.softmax(self.policy(x), dim=-1)
        
        # Value output is a single scalar
        value = self.value(x)
        
        return policy_probs, value

# Set the input and output dimensions based on CartPole
input_dim = 4
output_dim = 2

# Initialize the PPO agent
agent = PPOAgent(input_dim, output_dim)

# Test the network with a sample input
sample_state = torch.tensor(env.reset()[0], dtype=torch.float32)
policy_probs, value = agent(sample_state)
print("Policy probabilities:", policy_probs)
print("State value:", value)

# Define the optimizer
optimizer = optim.Adam(agent.parameters(), lr=1e-4)

# Define the PPO hyperparameters
clip_epsilon = 0.15  # Controls how much the policy can change
value_coef = 0.5  # Weight for value loss
entropy_coef = 0.01  # Weight for entropy bonus
batch_epochs = 3  # Number of update epochs per batch
batch_size = 128  # Size of mini-batches
# Out:
# Policy probabilities: tensor([0.5139, 0.4861], grad_fn=<SoftmaxBackward0>)
# State value: tensor([0.1304], grad_fn=<ViewBackward0>)

# %%
def compute_advantages(rewards, values, gamma=0.99, lam=0.95):
    advantages = []
    gae = 0
    # Add a final value of 0 if episode ended (or use last state's value if it didn't)
    values = values + [0]
    for i in reversed(range(len(rewards))):
        delta = rewards[i] + gamma * values[i + 1] - values[i]
        gae = delta + gamma * lam * gae
        advantages.insert(0, gae)
    
    return torch.tensor(advantages, dtype=torch.float32)

# %%
# Hyperparameters
STEPS_PER_EPOCH = 2048
EPOCHS = 1000

# Training loop
for epoch in range(EPOCHS):
    batch_data = []
    avg_life = []
    
    # Collect data for a batch
    while len(batch_data) < STEPS_PER_EPOCH:
        state = env.reset()[0]
        done = False
        
        # Collect data for a single episode
        lifetime = 0
        while not done:
            state_tensor = torch.tensor(state, dtype=torch.float32)
            policy_probs, value = agent(state_tensor)
            
            action_dist = torch.distributions.Categorical(policy_probs)
            action = action_dist.sample().item()
            next_state, reward, done, _, _ = env.step(action)
            
            batch_data.append((state, action, reward, next_state, value, done))
            state = next_state
            
            lifetime += 1
        
        avg_life.append(lifetime)
    
    # Process the batch data
    print(f"Processing epoch {epoch} data, avg life: {np.mean(avg_life)}")
    
    # Extract data
    states = torch.tensor(np.array([data[0] for data in batch_data]), dtype=torch.float32)
    actions = torch.tensor([data[1] for data in batch_data], dtype=torch.int64)
    rewards = [data[2] for data in batch_data]
    values = [data[4] for data in batch_data]

    # Compute advantages
    advantages = compute_advantages(rewards, values)
    #print("Advantages:", advantages)
    
    # Convert values and advantages to tensor
    values = torch.tensor(values, dtype=torch.float32)
    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
    #print("Normalized advantages:", advantages)
    
    for _ in range(batch_epochs):
        # Randomly shuffle the data
        indices = np.arange(len(states))
        np.random.shuffle(indices)
        
        states = states[indices]
        actions = actions[indices]
        advantages = advantages[indices]
        values = values[indices]
        
        for idx_start in range(0, len(states), batch_size):
            idx_end = idx_start + batch_size
            
            # Create a mini-batch
            batch_states = states[idx_start:idx_end]
            batch_actions = actions[idx_start:idx_end]
            batch_advantages = advantages[idx_start:idx_end]
            batch_values = values[idx_start:idx_end]
            
            # Get new policy and value predictions
            new_policy_probs, new_values = agent(batch_states)
            new_action_dist = torch.distributions.Categorical(new_policy_probs)
            
            # Calculate the log probabilities of the actions in the batch
            log_probs = new_action_dist.log_prob(batch_actions)
            old_log_probs = new_action_dist.log_prob(batch_actions).detach()
            
            # Policy ratio for PPO's clipped objective
            policy_ratio = torch.exp(log_probs - old_log_probs)
            surr1 = policy_ratio * batch_advantages
            surr2 = torch.clamp(policy_ratio, 1 - clip_epsilon, 1 + clip_epsilon) * batch_advantages
            policy_loss = -torch.min(surr1, surr2).mean()
            
            # Value loss
            value_loss = value_coef * (new_values.squeeze() - batch_values).pow(2).mean()

            # Entropy bonus to encourage exploration
            entropy = -torch.sum(new_policy_probs * torch.log(new_policy_probs + 1e-8), dim=-1).mean()
            entropy_loss = entropy_coef * entropy

            # Combine losses
            loss = policy_loss + value_loss + entropy_loss
            
            # Optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
# Out:
# Processing epoch 0 data, avg life: 22.445652173913043
# Processing epoch 1 data, avg life: 20.349514563106798
# Processing epoch 2 data, avg life: 20.78787878787879
# Processing epoch 3 data, avg life: 22.33695652173913
# Processing epoch 4 data, avg life: 23.247191011235955
# Processing epoch 5 data, avg life: 23.930232558139537
# Processing epoch 6 data, avg life: 24.746987951807228
# Processing epoch 7 data, avg life: 21.78723404255319
# Processing epoch 8 data, avg life: 24.5
# Processing epoch 9 data, avg life: 24.738095238095237
# Processing epoch 10 data, avg life: 24.97590361445783
# Processing epoch 11 data, avg life: 23.06741573033708
# Processing epoch 12 data, avg life: 26.075949367088608
# Processing epoch 13 data, avg life: 26.1125
# Processing epoch 14 data, avg life: 25.132530120481928
# Processing epoch 15 data, avg life: 26.31645569620253
# Processing epoch 16 data, avg life: 26.037974683544302
# Processing epoch 17 data, avg life: 26.911392405063292
# Processing epoch 18 data, avg life: 26.7012987012987
# Processing epoch 19 data, avg life: 24.698795180722893
# Processing epoch 20 data, avg life: 26.256410256410255
# Processing epoch 21 data, avg life: 24.651162790697676
# Processing epoch 22 data, avg life: 29.457142857142856
# Processing epoch 23 data, avg life: 25.20731707317073
# Processing epoch 24 data, avg life: 27.72972972972973
# Processing epoch 25 data, avg life: 24.464285714285715
# Processing epoch 26 data, avg life: 25.45679012345679
# Processing epoch 27 data, avg life: 26.87012987012987
# Processing epoch 28 data, avg life: 25.9
# Processing epoch 29 data, avg life: 23.632183908045977
# Processing epoch 30 data, avg life: 22.9
# Processing epoch 31 data, avg life: 20.948979591836736
# Processing epoch 32 data, avg life: 22.117021276595743
# Processing epoch 33 data, avg life: 24.11764705882353
# Processing epoch 34 data, avg life: 23.79310344827586
# Processing epoch 35 data, avg life: 26.973684210526315
# Processing epoch 36 data, avg life: 27.31578947368421
# Processing epoch 37 data, avg life: 27.945945945945947
# Processing epoch 38 data, avg life: 24.97590361445783
# Processing epoch 39 data, avg life: 26.397435897435898
# Processing epoch 40 data, avg life: 28.63888888888889
# Processing epoch 41 data, avg life: 30.970149253731343
# Processing epoch 42 data, avg life: 25.775
# Processing epoch 43 data, avg life: 27.605263157894736
# Processing epoch 44 data, avg life: 30.65671641791045
# Processing epoch 45 data, avg life: 30.147058823529413
# Processing epoch 46 data, avg life: 27.092105263157894
# Processing epoch 47 data, avg life: 27.586666666666666
# Processing epoch 48 data, avg life: 31.73846153846154
# Processing epoch 49 data, avg life: 29.557142857142857
# Processing epoch 50 data, avg life: 25.949367088607595
# Processing epoch 51 data, avg life: 23.71264367816092
# Processing epoch 52 data, avg life: 20.435643564356436
# Processing epoch 53 data, avg life: 21.819148936170212
# Processing epoch 54 data, avg life: 22.52747252747253
# Processing epoch 55 data, avg life: 26.294871794871796
# Processing epoch 56 data, avg life: 28.555555555555557
# Processing epoch 57 data, avg life: 28.2972972972973
# Processing epoch 58 data, avg life: 25.7375
# Processing epoch 59 data, avg life: 28.63888888888889
# Processing epoch 60 data, avg life: 28.068493150684933
# Processing epoch 61 data, avg life: 28.444444444444443
# Processing epoch 62 data, avg life: 29.34285714285714
# Processing epoch 63 data, avg life: 29.428571428571427
# Processing epoch 64 data, avg life: 28.28767123287671
# Processing epoch 65 data, avg life: 27.413333333333334
# Processing epoch 66 data, avg life: 32.06153846153846
# Processing epoch 67 data, avg life: 32.507936507936506
# Processing epoch 68 data, avg life: 26.74025974025974
# Processing epoch 69 data, avg life: 28.068493150684933
# Processing epoch 70 data, avg life: 40.18867924528302
# Processing epoch 71 data, avg life: 36.0
# Processing epoch 72 data, avg life: 34.15
# Processing epoch 73 data, avg life: 36.14035087719298
# Processing epoch 74 data, avg life: 36.982142857142854
# Processing epoch 75 data, avg life: 36.964285714285715
# Processing epoch 76 data, avg life: 36.31578947368421
# Processing epoch 77 data, avg life: 40.17307692307692
# Processing epoch 78 data, avg life: 39.528301886792455
# Processing epoch 79 data, avg life: 37.63636363636363
# Processing epoch 80 data, avg life: 37.85454545454545
# Processing epoch 81 data, avg life: 37.61818181818182
# Processing epoch 82 data, avg life: 34.86440677966102
# Processing epoch 83 data, avg life: 34.932203389830505
# Processing epoch 84 data, avg life: 44.020833333333336
# Processing epoch 85 data, avg life: 38.51851851851852
# Processing epoch 86 data, avg life: 40.470588235294116
# Processing epoch 87 data, avg life: 45.04347826086956
# Processing epoch 88 data, avg life: 42.326530612244895
# Processing epoch 89 data, avg life: 42.142857142857146
# Processing epoch 90 data, avg life: 35.41379310344828
# Processing epoch 91 data, avg life: 35.93103448275862
# Processing epoch 92 data, avg life: 36.0
# Processing epoch 93 data, avg life: 39.84905660377358
# Processing epoch 94 data, avg life: 37.67272727272727
# Processing epoch 95 data, avg life: 37.35087719298246
# Processing epoch 96 data, avg life: 38.886792452830186
# Processing epoch 97 data, avg life: 41.8
# Processing epoch 98 data, avg life: 42.450980392156865
# Processing epoch 99 data, avg life: 44.1063829787234
# Processing epoch 100 data, avg life: 39.60377358490566
# Processing epoch 101 data, avg life: 43.87234042553192
# Processing epoch 102 data, avg life: 38.074074074074076
# Processing epoch 103 data, avg life: 45.30434782608695
# Processing epoch 104 data, avg life: 49.18604651162791
# Processing epoch 105 data, avg life: 43.765957446808514
# Processing epoch 106 data, avg life: 34.233333333333334
# Processing epoch 107 data, avg life: 37.32727272727273
# Processing epoch 108 data, avg life: 42.326530612244895
# Processing epoch 109 data, avg life: 40.15384615384615
# Processing epoch 110 data, avg life: 40.94117647058823
# Processing epoch 111 data, avg life: 41.1
# Processing epoch 112 data, avg life: 36.10526315789474
# Processing epoch 113 data, avg life: 42.08163265306123
# Processing epoch 114 data, avg life: 49.19047619047619
# Processing epoch 115 data, avg life: 38.236363636363635
# Processing epoch 116 data, avg life: 42.16326530612245
# Processing epoch 117 data, avg life: 42.10204081632653
# Processing epoch 118 data, avg life: 41.3
# Processing epoch 119 data, avg life: 36.607142857142854
# Processing epoch 120 data, avg life: 38.092592592592595
# Processing epoch 121 data, avg life: 48.04651162790697
# Processing epoch 122 data, avg life: 50.34146341463415
# Processing epoch 123 data, avg life: 51.02439024390244
# Processing epoch 124 data, avg life: 50.073170731707314
# Processing epoch 125 data, avg life: 44.04255319148936
# Processing epoch 126 data, avg life: 44.659574468085104
# Processing epoch 127 data, avg life: 47.69767441860465
# Processing epoch 128 data, avg life: 60.6764705882353
# Processing epoch 129 data, avg life: 46.54545454545455
# Processing epoch 130 data, avg life: 52.51282051282051
# Processing epoch 131 data, avg life: 61.911764705882355
# Processing epoch 132 data, avg life: 47.0
# Processing epoch 133 data, avg life: 50.31707317073171
# Processing epoch 134 data, avg life: 44.0
# Processing epoch 135 data, avg life: 50.38095238095238
# Processing epoch 136 data, avg life: 55.81578947368421
# Processing epoch 137 data, avg life: 59.72222222222222
# Processing epoch 138 data, avg life: 49.76190476190476
# Processing epoch 139 data, avg life: 51.25
# Processing epoch 140 data, avg life: 35.49152542372882
# Processing epoch 141 data, avg life: 35.220338983050844
# Processing epoch 142 data, avg life: 33.435483870967744
# Processing epoch 143 data, avg life: 30.98507462686567
# Processing epoch 144 data, avg life: 34.94915254237288
# Processing epoch 145 data, avg life: 34.766666666666666
# Processing epoch 146 data, avg life: 37.42857142857143
# Processing epoch 147 data, avg life: 43.765957446808514
# Processing epoch 148 data, avg life: 45.8
# Processing epoch 149 data, avg life: 44.67391304347826
# Processing epoch 150 data, avg life: 52.5
# Processing epoch 151 data, avg life: 60.5
# Processing epoch 152 data, avg life: 59.74285714285714
# Processing epoch 153 data, avg life: 56.31578947368421
# Processing epoch 154 data, avg life: 60.94285714285714
# Processing epoch 155 data, avg life: 68.06451612903226
# Processing epoch 156 data, avg life: 67.54838709677419
# Processing epoch 157 data, avg life: 58.885714285714286
# Processing epoch 158 data, avg life: 69.6875
# Processing epoch 159 data, avg life: 60.6
# Processing epoch 160 data, avg life: 69.1
# Processing epoch 161 data, avg life: 64.6875
# Processing epoch 162 data, avg life: 65.0909090909091
# Processing epoch 163 data, avg life: 68.46666666666667
# Processing epoch 164 data, avg life: 72.93103448275862
# Processing epoch 165 data, avg life: 68.43333333333334
# Processing epoch 166 data, avg life: 101.0952380952381
# Processing epoch 167 data, avg life: 86.54166666666667
# Processing epoch 168 data, avg life: 73.89285714285714
# Processing epoch 169 data, avg life: 78.5925925925926
# Processing epoch 170 data, avg life: 67.54838709677419
# Processing epoch 171 data, avg life: 66.6774193548387
# Processing epoch 172 data, avg life: 66.19354838709677
# Processing epoch 173 data, avg life: 71.79310344827586
# Processing epoch 174 data, avg life: 74.86206896551724
# Processing epoch 175 data, avg life: 78.03703703703704
# Processing epoch 176 data, avg life: 82.08
# Processing epoch 177 data, avg life: 64.3125
# Processing epoch 178 data, avg life: 77.4074074074074
# Processing epoch 179 data, avg life: 63.14705882352941
# Processing epoch 180 data, avg life: 58.083333333333336
# Processing epoch 181 data, avg life: 60.61764705882353
# Processing epoch 182 data, avg life: 73.41379310344827
# Processing epoch 183 data, avg life: 84.07692307692308
# Processing epoch 184 data, avg life: 76.5
# Processing epoch 185 data, avg life: 83.96153846153847
# Processing epoch 186 data, avg life: 63.93939393939394
# Processing epoch 187 data, avg life: 52.425
# Processing epoch 188 data, avg life: 60.17142857142857
# Processing epoch 189 data, avg life: 62.303030303030305
# Processing epoch 190 data, avg life: 66.90322580645162
# Processing epoch 191 data, avg life: 45.75555555555555
# Processing epoch 192 data, avg life: 60.44117647058823
# Processing epoch 193 data, avg life: 74.41379310344827
# Processing epoch 194 data, avg life: 90.43478260869566
# Processing epoch 195 data, avg life: 78.96153846153847
# Processing epoch 196 data, avg life: 96.54545454545455
# Processing epoch 197 data, avg life: 108.95
# Processing epoch 198 data, avg life: 85.64
# Processing epoch 199 data, avg life: 65.9375
# Processing epoch 200 data, avg life: 73.57142857142857
# Processing epoch 201 data, avg life: 77.5925925925926
# Processing epoch 202 data, avg life: 114.27777777777777
# Processing epoch 203 data, avg life: 89.04166666666667
# Processing epoch 204 data, avg life: 129.125
# Processing epoch 205 data, avg life: 114.27777777777777
# Processing epoch 206 data, avg life: 90.34782608695652
# Processing epoch 207 data, avg life: 76.32142857142857
# Processing epoch 208 data, avg life: 70.76666666666667
# Processing epoch 209 data, avg life: 84.07692307692308
# Processing epoch 210 data, avg life: 104.75
# Processing epoch 211 data, avg life: 122.41176470588235
# Processing epoch 212 data, avg life: 126.57894736842105
# Processing epoch 213 data, avg life: 116.57894736842105
# Processing epoch 214 data, avg life: 115.33333333333333
# Processing epoch 215 data, avg life: 137.73333333333332
# Processing epoch 216 data, avg life: 103.9
# Processing epoch 217 data, avg life: 129.25
# Processing epoch 218 data, avg life: 105.85
# Processing epoch 219 data, avg life: 111.26315789473684
# Processing epoch 220 data, avg life: 117.0
# Processing epoch 221 data, avg life: 108.8
# Processing epoch 222 data, avg life: 104.3
# Processing epoch 223 data, avg life: 121.05882352941177
# Processing epoch 224 data, avg life: 94.5
# Processing epoch 225 data, avg life: 119.0
# Processing epoch 226 data, avg life: 114.77777777777777
# Processing epoch 227 data, avg life: 105.55
# Processing epoch 228 data, avg life: 93.77272727272727
# Processing epoch 229 data, avg life: 103.14285714285714
# Processing epoch 230 data, avg life: 82.92
# Processing epoch 231 data, avg life: 69.03333333333333
# Processing epoch 232 data, avg life: 53.02564102564103
# Processing epoch 233 data, avg life: 91.04347826086956
# Processing epoch 234 data, avg life: 103.75
# Processing epoch 235 data, avg life: 97.22727272727273
# Processing epoch 236 data, avg life: 93.4090909090909
# Processing epoch 237 data, avg life: 108.6842105263158
# Processing epoch 238 data, avg life: 130.875
# Processing epoch 239 data, avg life: 161.15384615384616
# Processing epoch 240 data, avg life: 167.30769230769232
# Processing epoch 241 data, avg life: 211.4
# Processing epoch 242 data, avg life: 172.0
# Processing epoch 243 data, avg life: 213.5
# Processing epoch 244 data, avg life: 152.85714285714286
# Processing epoch 245 data, avg life: 142.53333333333333
# Processing epoch 246 data, avg life: 167.5
# Processing epoch 247 data, avg life: 230.55555555555554
# Processing epoch 248 data, avg life: 131.1875
# Processing epoch 249 data, avg life: 158.3846153846154
# Processing epoch 250 data, avg life: 189.41666666666666
# Processing epoch 251 data, avg life: 175.08333333333334
# Processing epoch 252 data, avg life: 200.54545454545453
# Processing epoch 253 data, avg life: 204.54545454545453
# Processing epoch 254 data, avg life: 195.8181818181818
# Processing epoch 255 data, avg life: 191.8181818181818
# Processing epoch 256 data, avg life: 148.42857142857142
# Processing epoch 257 data, avg life: 110.4
# Processing epoch 258 data, avg life: 95.68181818181819
# Processing epoch 259 data, avg life: 103.7
# Processing epoch 260 data, avg life: 150.57142857142858
# Processing epoch 261 data, avg life: 150.0
# Processing epoch 262 data, avg life: 148.21428571428572
# Processing epoch 263 data, avg life: 112.6842105263158
# Processing epoch 264 data, avg life: 149.28571428571428
# Processing epoch 265 data, avg life: 261.375
# Processing epoch 266 data, avg life: 231.22222222222223
# Processing epoch 267 data, avg life: 237.0
# Processing epoch 268 data, avg life: 321.14285714285717
# Processing epoch 269 data, avg life: 206.45454545454547
# Processing epoch 270 data, avg life: 283.875
# Processing epoch 271 data, avg life: 277.0
# Processing epoch 272 data, avg life: 228.66666666666666
# Processing epoch 273 data, avg life: 267.0
# Processing epoch 274 data, avg life: 221.0
# Processing epoch 275 data, avg life: 187.0
# Processing epoch 276 data, avg life: 147.73333333333332
# Processing epoch 277 data, avg life: 148.57142857142858
# Processing epoch 278 data, avg life: 150.57142857142858
# Processing epoch 279 data, avg life: 173.33333333333334
# Processing epoch 280 data, avg life: 203.46153846153845
# Processing epoch 281 data, avg life: 215.8
# Processing epoch 282 data, avg life: 217.0
# Processing epoch 283 data, avg life: 229.6
# Processing epoch 284 data, avg life: 249.0
# Processing epoch 285 data, avg life: 229.44444444444446
# Processing epoch 286 data, avg life: 238.77777777777777
# Processing epoch 287 data, avg life: 163.23076923076923
# Processing epoch 288 data, avg life: 256.75
# Processing epoch 289 data, avg life: 162.07692307692307
# Processing epoch 290 data, avg life: 61.088235294117645
# Processing epoch 291 data, avg life: 80.26923076923077
# Processing epoch 292 data, avg life: 126.29411764705883
# Processing epoch 293 data, avg life: 121.82352941176471
# Processing epoch 294 data, avg life: 111.21052631578948
# Processing epoch 295 data, avg life: 118.5
# Processing epoch 296 data, avg life: 119.33333333333333
# Processing epoch 297 data, avg life: 165.92307692307693
# Processing epoch 298 data, avg life: 123.23529411764706
# Processing epoch 299 data, avg life: 144.73333333333332
# Processing epoch 300 data, avg life: 214.5
# Processing epoch 301 data, avg life: 283.25
# Processing epoch 302 data, avg life: 183.75
# Processing epoch 303 data, avg life: 204.9
# Processing epoch 304 data, avg life: 68.93548387096774
# Processing epoch 305 data, avg life: 57.648648648648646
# Processing epoch 306 data, avg life: 50.24390243902439
# Processing epoch 307 data, avg life: 62.294117647058826
# Processing epoch 308 data, avg life: 72.79310344827586
# Processing epoch 309 data, avg life: 64.46875
# Processing epoch 310 data, avg life: 84.68
# Processing epoch 311 data, avg life: 108.10526315789474
# Processing epoch 312 data, avg life: 128.1875
# Processing epoch 313 data, avg life: 160.23076923076923
# Processing epoch 314 data, avg life: 226.9090909090909
# Processing epoch 315 data, avg life: 240.11111111111111
# Processing epoch 316 data, avg life: 225.1
# Processing epoch 317 data, avg life: 247.22222222222223
# Processing epoch 318 data, avg life: 235.55555555555554
# Processing epoch 319 data, avg life: 217.1818181818182
# Processing epoch 320 data, avg life: 313.0
# Processing epoch 321 data, avg life: 243.88888888888889
# Processing epoch 322 data, avg life: 267.125
# Processing epoch 323 data, avg life: 263.875
# Processing epoch 324 data, avg life: 199.45454545454547
# Processing epoch 325 data, avg life: 194.45454545454547
# Processing epoch 326 data, avg life: 241.22222222222223
# Processing epoch 327 data, avg life: 267.875
# Processing epoch 328 data, avg life: 248.4
# Processing epoch 329 data, avg life: 188.27272727272728
# Processing epoch 330 data, avg life: 277.125
# Processing epoch 331 data, avg life: 239.55555555555554
# Processing epoch 332 data, avg life: 239.0
# Processing epoch 333 data, avg life: 269.75
# Processing epoch 334 data, avg life: 227.55555555555554
# Processing epoch 335 data, avg life: 254.88888888888889
# Processing epoch 336 data, avg life: 242.88888888888889
# Processing epoch 337 data, avg life: 228.22222222222223
# Processing epoch 338 data, avg life: 160.07692307692307
# Processing epoch 339 data, avg life: 98.33333333333333
# Processing epoch 340 data, avg life: 110.36842105263158
# Processing epoch 341 data, avg life: 110.36842105263158
# Processing epoch 342 data, avg life: 121.33333333333333
# Processing epoch 343 data, avg life: 118.38888888888889
# Processing epoch 344 data, avg life: 152.14285714285714
# Processing epoch 345 data, avg life: 161.6153846153846
# Processing epoch 346 data, avg life: 174.83333333333334
# Processing epoch 347 data, avg life: 122.11764705882354
# Processing epoch 348 data, avg life: 144.13333333333333
# Processing epoch 349 data, avg life: 131.8125
# Processing epoch 350 data, avg life: 149.57142857142858
# Processing epoch 351 data, avg life: 157.53846153846155
# Processing epoch 352 data, avg life: 173.5
# Processing epoch 353 data, avg life: 143.46666666666667
# Processing epoch 354 data, avg life: 171.33333333333334
# Processing epoch 355 data, avg life: 129.5625
# Processing epoch 356 data, avg life: 106.05
# Processing epoch 357 data, avg life: 159.07142857142858
# Processing epoch 358 data, avg life: 121.05882352941177
# Processing epoch 359 data, avg life: 163.92307692307693
# Processing epoch 360 data, avg life: 200.9090909090909
# Processing epoch 361 data, avg life: 159.07692307692307
# Processing epoch 362 data, avg life: 268.0
# Processing epoch 363 data, avg life: 294.875
# Processing epoch 364 data, avg life: 246.66666666666666
# Processing epoch 365 data, avg life: 366.0
# Processing epoch 366 data, avg life: 326.57142857142856
# Processing epoch 367 data, avg life: 373.42857142857144
# Processing epoch 368 data, avg life: 352.8333333333333
# Processing epoch 369 data, avg life: 516.25
# Processing epoch 370 data, avg life: 307.7142857142857
# Processing epoch 371 data, avg life: 282.875
# Processing epoch 372 data, avg life: 619.5
# Processing epoch 373 data, avg life: 256.1111111111111
# Processing epoch 374 data, avg life: 165.84615384615384
# Processing epoch 375 data, avg life: 124.05882352941177
# Processing epoch 376 data, avg life: 132.4375
# Processing epoch 377 data, avg life: 130.0
# Processing epoch 378 data, avg life: 127.17647058823529
# Processing epoch 379 data, avg life: 118.44444444444444
# Processing epoch 380 data, avg life: 136.25
# Processing epoch 381 data, avg life: 172.33333333333334
# Processing epoch 382 data, avg life: 165.07692307692307
# Processing epoch 383 data, avg life: 164.30769230769232
# Processing epoch 384 data, avg life: 188.66666666666666
# Processing epoch 385 data, avg life: 159.28571428571428
# Processing epoch 386 data, avg life: 162.92307692307693
# Processing epoch 387 data, avg life: 180.0
# Processing epoch 388 data, avg life: 188.27272727272728
# Processing epoch 389 data, avg life: 217.2
# Processing epoch 390 data, avg life: 192.72727272727272
# Processing epoch 391 data, avg life: 274.25
# Processing epoch 392 data, avg life: 230.44444444444446
# Processing epoch 393 data, avg life: 212.6
# Processing epoch 394 data, avg life: 195.45454545454547
# Processing epoch 395 data, avg life: 193.9090909090909
# Processing epoch 396 data, avg life: 233.33333333333334
# Processing epoch 397 data, avg life: 210.4
# Processing epoch 398 data, avg life: 239.11111111111111
# Processing epoch 399 data, avg life: 230.33333333333334
# Processing epoch 400 data, avg life: 272.5
# Processing epoch 401 data, avg life: 268.75
# Processing epoch 402 data, avg life: 234.33333333333334
# Processing epoch 403 data, avg life: 452.2
# Processing epoch 404 data, avg life: 500.0
# Processing epoch 405 data, avg life: 293.75
# Processing epoch 406 data, avg life: 351.0
# Processing epoch 407 data, avg life: 312.0
# Processing epoch 408 data, avg life: 161.3846153846154
# Processing epoch 409 data, avg life: 167.46153846153845
# Processing epoch 410 data, avg life: 540.75
# Processing epoch 411 data, avg life: 494.2
# Processing epoch 412 data, avg life: 336.5
# Processing epoch 413 data, avg life: 752.25
# Processing epoch 414 data, avg life: 523.2
# Processing epoch 415 data, avg life: 439.0
# Processing epoch 416 data, avg life: 1038.0
# Processing epoch 417 data, avg life: 344.3333333333333
# Processing epoch 418 data, avg life: 352.0
# Processing epoch 419 data, avg life: 269.6666666666667
# Processing epoch 420 data, avg life: 804.6666666666666
# Processing epoch 421 data, avg life: 389.1666666666667
# Processing epoch 422 data, avg life: 317.7142857142857
# Processing epoch 423 data, avg life: 415.4
# Processing epoch 424 data, avg life: 445.2
# Processing epoch 425 data, avg life: 338.7142857142857
# Processing epoch 426 data, avg life: 722.0
# Processing epoch 427 data, avg life: 431.3333333333333
# Processing epoch 428 data, avg life: 419.6
# Processing epoch 429 data, avg life: 324.85714285714283
# Processing epoch 430 data, avg life: 301.125
# Processing epoch 431 data, avg life: 376.1666666666667
# Processing epoch 432 data, avg life: 414.2857142857143
# Processing epoch 433 data, avg life: 1035.0
# Processing epoch 434 data, avg life: 418.1666666666667
# Processing epoch 435 data, avg life: 351.8333333333333
# Processing epoch 436 data, avg life: 452.2
# Processing epoch 437 data, avg life: 439.1666666666667
# Processing epoch 438 data, avg life: 692.3333333333334
# Processing epoch 439 data, avg life: 442.6666666666667
# Processing epoch 440 data, avg life: 426.0
# Processing epoch 441 data, avg life: 691.3333333333334
# Processing epoch 442 data, avg life: 589.5
# Processing epoch 443 data, avg life: 540.25
# Processing epoch 444 data, avg life: 255.55555555555554
# Processing epoch 445 data, avg life: 269.125
# Processing epoch 446 data, avg life: 204.63636363636363
# Processing epoch 447 data, avg life: 209.6
# Processing epoch 448 data, avg life: 238.33333333333334
# Processing epoch 449 data, avg life: 367.3333333333333
# Processing epoch 450 data, avg life: 408.1666666666667
# Processing epoch 451 data, avg life: 874.3333333333334
# Processing epoch 452 data, avg life: 861.3333333333334
# Processing epoch 453 data, avg life: 398.5
# Processing epoch 454 data, avg life: 410.6
# Processing epoch 455 data, avg life: 537.5
# Processing epoch 456 data, avg life: 572.0
# Processing epoch 457 data, avg life: 342.5
# Processing epoch 458 data, avg life: 157.84615384615384
# Processing epoch 459 data, avg life: 109.63157894736842
# Processing epoch 460 data, avg life: 86.41666666666667
# Processing epoch 461 data, avg life: 86.125
# Processing epoch 462 data, avg life: 101.47619047619048
# Processing epoch 463 data, avg life: 106.9
# Processing epoch 464 data, avg life: 112.94736842105263
# Processing epoch 465 data, avg life: 119.38888888888889
# Processing epoch 466 data, avg life: 131.875
# Processing epoch 467 data, avg life: 132.5
# Processing epoch 468 data, avg life: 134.3125
# Processing epoch 469 data, avg life: 134.875
# Processing epoch 470 data, avg life: 132.6875
# Processing epoch 471 data, avg life: 128.75
# Processing epoch 472 data, avg life: 130.9375
# Processing epoch 473 data, avg life: 129.625
# Processing epoch 474 data, avg life: 91.47826086956522
# Processing epoch 475 data, avg life: 86.33333333333333
# Processing epoch 476 data, avg life: 125.29411764705883
# Processing epoch 477 data, avg life: 117.88888888888889
# Processing epoch 478 data, avg life: 133.9375
# Processing epoch 479 data, avg life: 129.1764705882353
# Processing epoch 480 data, avg life: 128.25
# Processing epoch 481 data, avg life: 163.76923076923077
# Processing epoch 482 data, avg life: 160.23076923076923
# Processing epoch 483 data, avg life: 151.14285714285714
# Processing epoch 484 data, avg life: 193.36363636363637
# Processing epoch 485 data, avg life: 179.41666666666666
# Processing epoch 486 data, avg life: 168.07692307692307
# Processing epoch 487 data, avg life: 302.125
# Processing epoch 488 data, avg life: 553.2
# Processing epoch 489 data, avg life: 439.8
# Processing epoch 490 data, avg life: 484.8
# Processing epoch 491 data, avg life: 360.6666666666667
# Processing epoch 492 data, avg life: 556.25
# Processing epoch 493 data, avg life: 616.75
# Processing epoch 494 data, avg life: 372.0
# Processing epoch 495 data, avg life: 293.42857142857144
# Processing epoch 496 data, avg life: 270.875
# Processing epoch 497 data, avg life: 267.375
# Processing epoch 498 data, avg life: 217.4
# Processing epoch 499 data, avg life: 220.4
# Processing epoch 500 data, avg life: 259.875
# Processing epoch 501 data, avg life: 365.6666666666667
# Processing epoch 502 data, avg life: 721.3333333333334
# Processing epoch 503 data, avg life: 424.6
# Processing epoch 504 data, avg life: 837.6666666666666
# Processing epoch 505 data, avg life: 1033.0
# Processing epoch 506 data, avg life: 970.3333333333334
# Processing epoch 507 data, avg life: 2144.0
# Processing epoch 508 data, avg life: 861.3333333333334
# Processing epoch 509 data, avg life: 584.0
# Processing epoch 510 data, avg life: 390.5
# Processing epoch 511 data, avg life: 205.1
# Processing epoch 512 data, avg life: 125.94117647058823
# Processing epoch 513 data, avg life: 84.68
# Processing epoch 514 data, avg life: 80.46153846153847
# Processing epoch 515 data, avg life: 89.65217391304348
# Processing epoch 516 data, avg life: 79.84615384615384
# Processing epoch 517 data, avg life: 95.27272727272727
# Processing epoch 518 data, avg life: 84.48
# Processing epoch 519 data, avg life: 94.72727272727273
# Processing epoch 520 data, avg life: 87.16666666666667
# Processing epoch 521 data, avg life: 98.42857142857143
# Processing epoch 522 data, avg life: 102.55
# Processing epoch 523 data, avg life: 150.21428571428572
# Processing epoch 524 data, avg life: 172.91666666666666
# Processing epoch 525 data, avg life: 136.8
# Processing epoch 526 data, avg life: 153.64285714285714
# Processing epoch 527 data, avg life: 154.35714285714286
# Processing epoch 528 data, avg life: 173.5
# Processing epoch 529 data, avg life: 171.66666666666666
# Processing epoch 530 data, avg life: 159.76923076923077
# Processing epoch 531 data, avg life: 169.3846153846154
# Processing epoch 532 data, avg life: 171.91666666666666
# Processing epoch 533 data, avg life: 180.0
# Processing epoch 534 data, avg life: 184.66666666666666
# Processing epoch 535 data, avg life: 206.5
# Processing epoch 536 data, avg life: 233.55555555555554
# Processing epoch 537 data, avg life: 238.66666666666666
# Processing epoch 538 data, avg life: 260.375
# Processing epoch 539 data, avg life: 247.33333333333334
# Processing epoch 540 data, avg life: 218.2
# Processing epoch 541 data, avg life: 230.0
# Processing epoch 542 data, avg life: 356.42857142857144
# Processing epoch 543 data, avg life: 254.77777777777777
# Processing epoch 544 data, avg life: 261.0
# Processing epoch 545 data, avg life: 218.0
# Processing epoch 546 data, avg life: 161.84615384615384
# Processing epoch 547 data, avg life: 137.93333333333334
# Processing epoch 548 data, avg life: 126.29411764705883
# Processing epoch 549 data, avg life: 120.16666666666667
# Processing epoch 550 data, avg life: 126.0
# Processing epoch 551 data, avg life: 118.72222222222223
# Processing epoch 552 data, avg life: 117.5
# Processing epoch 553 data, avg life: 120.72222222222223
# Processing epoch 554 data, avg life: 115.83333333333333
# Processing epoch 555 data, avg life: 114.11111111111111
# Processing epoch 556 data, avg life: 146.92857142857142
# Processing epoch 557 data, avg life: 178.33333333333334
# Processing epoch 558 data, avg life: 220.7
# Processing epoch 559 data, avg life: 236.8
# Processing epoch 560 data, avg life: 244.88888888888889
# Processing epoch 561 data, avg life: 271.0
# Processing epoch 562 data, avg life: 234.33333333333334
# Processing epoch 563 data, avg life: 227.3
# Processing epoch 564 data, avg life: 305.0
# Processing epoch 565 data, avg life: 435.0
# Processing epoch 566 data, avg life: 268.0
# Processing epoch 567 data, avg life: 328.42857142857144
# Processing epoch 568 data, avg life: 285.0
# Processing epoch 569 data, avg life: 286.75
# Processing epoch 570 data, avg life: 419.3333333333333
# Processing epoch 571 data, avg life: 279.5
# Processing epoch 572 data, avg life: 835.25
# Processing epoch 573 data, avg life: 460.6
# Processing epoch 574 data, avg life: 557.5
# Processing epoch 575 data, avg life: 780.0
# Processing epoch 576 data, avg life: 737.5
# Processing epoch 577 data, avg life: 193.36363636363637
# Processing epoch 578 data, avg life: 131.0
# Processing epoch 579 data, avg life: 120.72222222222223
# Processing epoch 580 data, avg life: 121.23529411764706
# Processing epoch 581 data, avg life: 142.2
# Processing epoch 582 data, avg life: 166.69230769230768
# Processing epoch 583 data, avg life: 178.5
# Processing epoch 584 data, avg life: 177.08333333333334
# Processing epoch 585 data, avg life: 188.9090909090909
# Processing epoch 586 data, avg life: 161.84615384615384
# Processing epoch 587 data, avg life: 169.30769230769232
# Processing epoch 588 data, avg life: 155.92857142857142
# Processing epoch 589 data, avg life: 91.65217391304348
# Processing epoch 590 data, avg life: 70.83333333333333
# Processing epoch 591 data, avg life: 78.96153846153847
# Processing epoch 592 data, avg life: 107.0
# Processing epoch 593 data, avg life: 116.5
# Processing epoch 594 data, avg life: 115.42105263157895
# Processing epoch 595 data, avg life: 114.21052631578948
# Processing epoch 596 data, avg life: 132.375
# Processing epoch 597 data, avg life: 139.75
# Processing epoch 598 data, avg life: 149.07142857142858
# Processing epoch 599 data, avg life: 153.35714285714286
# Processing epoch 600 data, avg life: 170.75
# Processing epoch 601 data, avg life: 112.21052631578948
# Processing epoch 602 data, avg life: 75.88888888888889
# Processing epoch 603 data, avg life: 124.6470588235294
# Processing epoch 604 data, avg life: 168.84615384615384
# Processing epoch 605 data, avg life: 159.46153846153845
# Processing epoch 606 data, avg life: 169.3846153846154
# Processing epoch 607 data, avg life: 173.58333333333334
# Processing epoch 608 data, avg life: 170.83333333333334
# Processing epoch 609 data, avg life: 180.75
# Processing epoch 610 data, avg life: 167.46153846153845
# Processing epoch 611 data, avg life: 148.71428571428572
# Processing epoch 612 data, avg life: 133.8125
# Processing epoch 613 data, avg life: 136.8
# Processing epoch 614 data, avg life: 174.23076923076923
# Processing epoch 615 data, avg life: 194.0
# Processing epoch 616 data, avg life: 200.0909090909091
# Processing epoch 617 data, avg life: 198.0
# Processing epoch 618 data, avg life: 183.25
# Processing epoch 619 data, avg life: 182.66666666666666
# Processing epoch 620 data, avg life: 161.6153846153846
# Processing epoch 621 data, avg life: 186.27272727272728
# Processing epoch 622 data, avg life: 140.26666666666668
# Processing epoch 623 data, avg life: 106.2
# Processing epoch 624 data, avg life: 103.95
# Processing epoch 625 data, avg life: 93.77272727272727
# Processing epoch 626 data, avg life: 105.75
# Processing epoch 627 data, avg life: 113.10526315789474
# Processing epoch 628 data, avg life: 94.95454545454545
# Processing epoch 629 data, avg life: 105.15
# Processing epoch 630 data, avg life: 107.2
# Processing epoch 631 data, avg life: 109.36842105263158
# Processing epoch 632 data, avg life: 105.7
# Processing epoch 633 data, avg life: 106.25
# Processing epoch 634 data, avg life: 114.66666666666667
# Processing epoch 635 data, avg life: 108.36842105263158
# Processing epoch 636 data, avg life: 119.66666666666667
# Processing epoch 637 data, avg life: 135.9375
# Processing epoch 638 data, avg life: 128.875
# Processing epoch 639 data, avg life: 138.13333333333333
# Processing epoch 640 data, avg life: 130.5
# Processing epoch 641 data, avg life: 136.66666666666666
# Processing epoch 642 data, avg life: 165.15384615384616
# Processing epoch 643 data, avg life: 193.63636363636363
# Processing epoch 644 data, avg life: 177.66666666666666
# Processing epoch 645 data, avg life: 194.41666666666666
# Processing epoch 646 data, avg life: 172.16666666666666
# Processing epoch 647 data, avg life: 187.0
# Processing epoch 648 data, avg life: 192.54545454545453
# Processing epoch 649 data, avg life: 216.1818181818182
# Processing epoch 650 data, avg life: 195.45454545454547
# Processing epoch 651 data, avg life: 212.4
# Processing epoch 652 data, avg life: 194.0
# Processing epoch 653 data, avg life: 210.2
# Processing epoch 654 data, avg life: 198.54545454545453
# Processing epoch 655 data, avg life: 206.41666666666666
# Processing epoch 656 data, avg life: 317.57142857142856
# Processing epoch 657 data, avg life: 303.85714285714283
# Processing epoch 658 data, avg life: 279.3333333333333
# Processing epoch 659 data, avg life: 297.125
# Processing epoch 660 data, avg life: 306.85714285714283
# Processing epoch 661 data, avg life: 214.7
# Processing epoch 662 data, avg life: 282.75
# Processing epoch 663 data, avg life: 314.2857142857143
# Processing epoch 664 data, avg life: 232.11111111111111
# Processing epoch 665 data, avg life: 196.54545454545453
# Processing epoch 666 data, avg life: 221.8181818181818
# Processing epoch 667 data, avg life: 228.7
# Processing epoch 668 data, avg life: 300.0
# Processing epoch 669 data, avg life: 236.33333333333334
# Processing epoch 670 data, avg life: 293.85714285714283
# Processing epoch 671 data, avg life: 250.22222222222223
# Processing epoch 672 data, avg life: 282.375
# Processing epoch 673 data, avg life: 262.375
# Processing epoch 674 data, avg life: 275.75
# Processing epoch 675 data, avg life: 231.0
# Processing epoch 676 data, avg life: 266.5
# Processing epoch 677 data, avg life: 206.4
# Processing epoch 678 data, avg life: 264.375
# Processing epoch 679 data, avg life: 275.25
# Processing epoch 680 data, avg life: 267.1111111111111
# Processing epoch 681 data, avg life: 190.9090909090909
# Processing epoch 682 data, avg life: 231.77777777777777
# Processing epoch 683 data, avg life: 229.11111111111111
# Processing epoch 684 data, avg life: 218.72727272727272
# Processing epoch 685 data, avg life: 270.125
# Processing epoch 686 data, avg life: 231.66666666666666
# Processing epoch 687 data, avg life: 218.6
# Processing epoch 688 data, avg life: 231.9090909090909
# Processing epoch 689 data, avg life: 151.64285714285714
# Processing epoch 690 data, avg life: 140.33333333333334
# Processing epoch 691 data, avg life: 143.6
# Processing epoch 692 data, avg life: 154.78571428571428
# Processing epoch 693 data, avg life: 149.42857142857142
# Processing epoch 694 data, avg life: 143.13333333333333
# Processing epoch 695 data, avg life: 141.2
# Processing epoch 696 data, avg life: 140.13333333333333
# Processing epoch 697 data, avg life: 139.8
# Processing epoch 698 data, avg life: 133.0625
# Processing epoch 699 data, avg life: 147.57142857142858
# Processing epoch 700 data, avg life: 157.92307692307693
# Processing epoch 701 data, avg life: 172.92307692307693
# Processing epoch 702 data, avg life: 221.5
# Processing epoch 703 data, avg life: 226.6
# Processing epoch 704 data, avg life: 232.1
# Processing epoch 705 data, avg life: 194.72727272727272
# Processing epoch 706 data, avg life: 195.27272727272728
# Processing epoch 707 data, avg life: 252.11111111111111
# Processing epoch 708 data, avg life: 233.33333333333334
# Processing epoch 709 data, avg life: 262.0
# Processing epoch 710 data, avg life: 207.4
# Processing epoch 711 data, avg life: 200.72727272727272
# Processing epoch 712 data, avg life: 192.63636363636363
# Processing epoch 713 data, avg life: 176.83333333333334
# Processing epoch 714 data, avg life: 176.58333333333334
# Processing epoch 715 data, avg life: 214.1818181818182
# Processing epoch 716 data, avg life: 238.22222222222223
# Processing epoch 717 data, avg life: 209.5
# Processing epoch 718 data, avg life: 181.75
# Processing epoch 719 data, avg life: 248.77777777777777
# Processing epoch 720 data, avg life: 243.44444444444446
# Processing epoch 721 data, avg life: 283.0
# Processing epoch 722 data, avg life: 314.14285714285717
# Processing epoch 723 data, avg life: 247.44444444444446
# Processing epoch 724 data, avg life: 174.41666666666666
# Processing epoch 725 data, avg life: 163.30769230769232
# Processing epoch 726 data, avg life: 149.85714285714286
# Processing epoch 727 data, avg life: 172.53846153846155
# Processing epoch 728 data, avg life: 196.9090909090909
# Processing epoch 729 data, avg life: 214.3
# Processing epoch 730 data, avg life: 205.36363636363637
# Processing epoch 731 data, avg life: 237.77777777777777
# Processing epoch 732 data, avg life: 308.7142857142857
# Processing epoch 733 data, avg life: 261.25
# Processing epoch 734 data, avg life: 230.22222222222223
# Processing epoch 735 data, avg life: 236.2
# Processing epoch 736 data, avg life: 166.15384615384616
# Processing epoch 737 data, avg life: 201.27272727272728
# Processing epoch 738 data, avg life: 165.07692307692307
# Processing epoch 739 data, avg life: 270.25
# Processing epoch 740 data, avg life: 274.75
# Processing epoch 741 data, avg life: 271.125
# Processing epoch 742 data, avg life: 305.7142857142857
# Processing epoch 743 data, avg life: 218.6
# Processing epoch 744 data, avg life: 354.0
# Processing epoch 745 data, avg life: 290.125
# Processing epoch 746 data, avg life: 216.1
# Processing epoch 747 data, avg life: 177.75
# Processing epoch 748 data, avg life: 159.76923076923077
# Processing epoch 749 data, avg life: 164.6153846153846
# Processing epoch 750 data, avg life: 283.125
# Processing epoch 751 data, avg life: 217.2
# Processing epoch 752 data, avg life: 218.8
# Processing epoch 753 data, avg life: 343.1666666666667
# Processing epoch 754 data, avg life: 349.3333333333333
# Processing epoch 755 data, avg life: 346.85714285714283
# Processing epoch 756 data, avg life: 318.2857142857143
# Processing epoch 757 data, avg life: 373.3333333333333
# Processing epoch 758 data, avg life: 377.3333333333333
# Processing epoch 759 data, avg life: 322.57142857142856
# Processing epoch 760 data, avg life: 346.3333333333333
# Processing epoch 761 data, avg life: 338.85714285714283
# Processing epoch 762 data, avg life: 293.375
# Processing epoch 763 data, avg life: 314.2857142857143
# Processing epoch 764 data, avg life: 260.75
# Processing epoch 765 data, avg life: 165.6153846153846
# Processing epoch 766 data, avg life: 177.0
# Processing epoch 767 data, avg life: 197.54545454545453
# Processing epoch 768 data, avg life: 206.9
# Processing epoch 769 data, avg life: 311.57142857142856
# Processing epoch 770 data, avg life: 238.55555555555554
# Processing epoch 771 data, avg life: 238.0
# Processing epoch 772 data, avg life: 222.2
# Processing epoch 773 data, avg life: 214.5
# Processing epoch 774 data, avg life: 229.44444444444446
# Processing epoch 775 data, avg life: 247.22222222222223
# Processing epoch 776 data, avg life: 220.0
# Processing epoch 777 data, avg life: 281.0
# Processing epoch 778 data, avg life: 293.57142857142856
# Processing epoch 779 data, avg life: 266.6666666666667
# Processing epoch 780 data, avg life: 232.0
# Processing epoch 781 data, avg life: 211.3
# Processing epoch 782 data, avg life: 208.2
# Processing epoch 783 data, avg life: 195.0909090909091
# Processing epoch 784 data, avg life: 190.54545454545453
# Processing epoch 785 data, avg life: 201.1818181818182
# Processing epoch 786 data, avg life: 207.9090909090909
# Processing epoch 787 data, avg life: 246.0
# Processing epoch 788 data, avg life: 335.42857142857144
# Processing epoch 789 data, avg life: 251.22222222222223
# Processing epoch 790 data, avg life: 277.875
# Processing epoch 791 data, avg life: 305.375
# Processing epoch 792 data, avg life: 367.8333333333333
# Processing epoch 793 data, avg life: 347.0
# Processing epoch 794 data, avg life: 286.625
# Processing epoch 795 data, avg life: 278.375
# Processing epoch 796 data, avg life: 255.66666666666666
# Processing epoch 797 data, avg life: 285.25
# Processing epoch 798 data, avg life: 269.5
# Processing epoch 799 data, avg life: 270.375
# Processing epoch 800 data, avg life: 264.375
# Processing epoch 801 data, avg life: 289.75
# Processing epoch 802 data, avg life: 332.7142857142857
# Processing epoch 803 data, avg life: 530.0
# Processing epoch 804 data, avg life: 1040.0
# Processing epoch 805 data, avg life: 456.8
# Processing epoch 806 data, avg life: 288.5
# Processing epoch 807 data, avg life: 297.57142857142856
# Processing epoch 808 data, avg life: 784.3333333333334
# Processing epoch 809 data, avg life: 964.0
# Processing epoch 810 data, avg life: 866.6666666666666
# Processing epoch 811 data, avg life: 1458.0
# Processing epoch 812 data, avg life: 732.3333333333334
# Processing epoch 813 data, avg life: 5903.0
# Processing epoch 814 data, avg life: 2575.5
# Processing epoch 815 data, avg life: 866.3333333333334
# Processing epoch 816 data, avg life: 601.5
# Processing epoch 817 data, avg life: 926.0
# Processing epoch 818 data, avg life: 2066.5
# Processing epoch 819 data, avg life: 16500.0
# Processing epoch 820 data, avg life: 41397.0
# Processing epoch 821 data, avg life: 2931.0
# Processing epoch 822 data, avg life: 591.5
# Processing epoch 823 data, avg life: 473.8
# Processing epoch 824 data, avg life: 381.3333333333333
# Processing epoch 825 data, avg life: 321.2857142857143
# Processing epoch 826 data, avg life: 342.8333333333333
# Processing epoch 827 data, avg life: 780.0
# Processing epoch 828 data, avg life: 2472.0
# Processing epoch 829 data, avg life: 14549.0
# Processing epoch 830 data, avg life: 30244.0
# Processing epoch 831 data, avg life: 1149.0
# Processing epoch 832 data, avg life: 467.8
# Processing epoch 833 data, avg life: 366.8333333333333
# Processing epoch 834 data, avg life: 257.44444444444446
# Processing epoch 835 data, avg life: 170.66666666666666
# Processing epoch 836 data, avg life: 146.5
# Processing epoch 837 data, avg life: 133.1875
# Processing epoch 838 data, avg life: 119.38888888888889
# Processing epoch 839 data, avg life: 126.0
# Processing epoch 840 data, avg life: 121.3529411764706
# Processing epoch 841 data, avg life: 117.55555555555556
# Processing epoch 842 data, avg life: 112.47368421052632
# Processing epoch 843 data, avg life: 107.78947368421052
# Processing epoch 844 data, avg life: 109.10526315789474
# Processing epoch 845 data, avg life: 110.84210526315789
# Processing epoch 846 data, avg life: 120.38888888888889
# Processing epoch 847 data, avg life: 122.52941176470588
# Processing epoch 848 data, avg life: 115.44444444444444
# Processing epoch 849 data, avg life: 122.52941176470588
# Processing epoch 850 data, avg life: 111.3157894736842
# Processing epoch 851 data, avg life: 105.6
# Processing epoch 852 data, avg life: 101.76190476190476
# Processing epoch 853 data, avg life: 106.0
# Processing epoch 854 data, avg life: 102.55
# Processing epoch 855 data, avg life: 119.83333333333333
# Processing epoch 856 data, avg life: 128.0
# Processing epoch 857 data, avg life: 129.8125
# Processing epoch 858 data, avg life: 134.8125
# Processing epoch 859 data, avg life: 137.53333333333333
# Processing epoch 860 data, avg life: 144.0
# Processing epoch 861 data, avg life: 150.85714285714286
# Processing epoch 862 data, avg life: 154.71428571428572
# Processing epoch 863 data, avg life: 156.71428571428572
# Processing epoch 864 data, avg life: 154.42857142857142
# Processing epoch 865 data, avg life: 145.0
# Processing epoch 866 data, avg life: 148.5
# Processing epoch 867 data, avg life: 147.92857142857142
# Processing epoch 868 data, avg life: 139.06666666666666
# Processing epoch 869 data, avg life: 130.25
# Processing epoch 870 data, avg life: 124.88235294117646
# Processing epoch 871 data, avg life: 119.66666666666667
# Processing epoch 872 data, avg life: 120.11111111111111
# Processing epoch 873 data, avg life: 123.70588235294117
# Processing epoch 874 data, avg life: 118.61111111111111
# Processing epoch 875 data, avg life: 119.72222222222223
# Processing epoch 876 data, avg life: 120.82352941176471
# Processing epoch 877 data, avg life: 118.94444444444444
# Processing epoch 878 data, avg life: 107.89473684210526
# Processing epoch 879 data, avg life: 121.6470588235294
# Processing epoch 880 data, avg life: 139.73333333333332
# Processing epoch 881 data, avg life: 140.0
# Processing epoch 882 data, avg life: 137.66666666666666
# Processing epoch 883 data, avg life: 145.0
# Processing epoch 884 data, avg life: 157.14285714285714
# Processing epoch 885 data, avg life: 150.07142857142858
# Processing epoch 886 data, avg life: 147.85714285714286
# Processing epoch 887 data, avg life: 146.86666666666667
# Processing epoch 888 data, avg life: 153.64285714285714
# Processing epoch 889 data, avg life: 149.64285714285714
# Processing epoch 890 data, avg life: 143.0
# Processing epoch 891 data, avg life: 159.84615384615384
# Processing epoch 892 data, avg life: 145.26666666666668
# Processing epoch 893 data, avg life: 133.0625
# Processing epoch 894 data, avg life: 132.9375
# Processing epoch 895 data, avg life: 124.52941176470588
# Processing epoch 896 data, avg life: 131.125
# Processing epoch 897 data, avg life: 129.1875
# Processing epoch 898 data, avg life: 126.70588235294117
# Processing epoch 899 data, avg life: 124.41176470588235
# Processing epoch 900 data, avg life: 124.29411764705883
# Processing epoch 901 data, avg life: 127.52941176470588
# Processing epoch 902 data, avg life: 122.05882352941177
# Processing epoch 903 data, avg life: 127.23529411764706
# Processing epoch 904 data, avg life: 131.9375
# Processing epoch 905 data, avg life: 130.625
# Processing epoch 906 data, avg life: 132.25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 21
#      18 state_tensor = torch.tensor(state, dtype=torch.float32)
#      19 policy_probs, value = agent(state_tensor)
# ---> 21 action_dist = torch.distributions.Categorical(policy_probs)
#      22 action = action_dist.sample().item()
#      23 next_state, reward, done, _, _ = env.step(action)
#
# File ~/miniconda3/envs/PPOgym/lib/python3.12/site-packages/torch/distributions/categorical.py:70, in Categorical.__init__(self, probs, logits, validate_args)
#      66 self._num_events = self._param.size()[-1]
#      67 batch_shape = (
#      68     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      69 )
# ---> 70 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/miniconda3/envs/PPOgym/lib/python3.12/site-packages/torch/distributions/distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:
